# %%
pip install google-adk
# Out:
# Requirement already satisfied: google-adk in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (1.19.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (6.0.3)
# Requirement already satisfied: aiosqlite>=0.21.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.21.0)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (4.11.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.6.5)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (8.3.0)
# Requirement already satisfied: fastapi<0.119.0,>=0.115.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.118.3)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.187.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.125.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.126.1)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.0.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-bigquery>=2.2.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (3.38.0)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.25.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (3.59.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=3.0.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (3.5.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.45.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.49.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.21)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (4.25.1)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.21.0)
# Requirement already satisfied: opentelemetry-api<=1.37.0,>=1.37.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<=1.37.0,>=1.37.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: pyarrow>=14.0.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (22.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.12.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in c:\users\adity\appdata\roaming\python\python312\site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.32.5)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.17.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.0.44)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.48.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (9.1.2)
# Requirement already satisfied: typing-extensions<5,>=4.5 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.38.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.1)
# Requirement already satisfied: cryptography in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from authlib<2.0.0,>=1.5.1->google-adk) (46.0.3)
# Requirement already satisfied: colorama in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from click<9.0.0,>=8.1.8->google-adk) (0.4.6)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.43.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.33.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: packaging>=14.3 in c:\users\adity\appdata\roaming\python\python312\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (24.2)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.17.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.7.2)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.4.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.14.3)
# Requirement already satisfied: sqlparse>=0.4.4 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-storage<4.0.0,>=3.0.0->google-adk) (1.7.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from google-genai<2.0.0,>=1.45.0->google-adk) (0.28.1)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.1)
# Requirement already satisfied: certifi in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.28.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (3.0.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (3.23.0)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk) (2.28.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-sdk<=1.37.0,>=1.37.0->google-adk) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\adity\appdata\roaming\python\python312\site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.6.1)
# Requirement already satisfied: numpy>=1.21 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.2.3)
# Requirement already satisfied: greenlet>=1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.2.4)
# Requirement already satisfied: tzdata in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from tzlocal<6.0,>=5.3->google-adk) (2025.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.23)
# Requirement already satisfied: alembic in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.17.1)
# Requirement already satisfied: Mako in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os 
from dotenv import load_dotenv

load_dotenv()


try:
    GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
    if GOOGLE_API_KEY:
        print("API key is setup Successfully !")
    else:
        raise ValueError(f"Your API key is not Setup yet Check .env file")
except Exception as e:
    print(f"Error Occurred: {e}")
# Out:
# API key is setup Successfully !

# %%
from google.adk.agents import Agent
from google.adk.runners import InMemoryRunner
from google.adk.models.google_llm import Gemini
from google.adk.tools import google_search
from google.genai import types

print("ADK components imported successfully.")
# Out:
# ADK components imported successfully.

# %%
from IPython.display import display, HTML


def get_adk_proxy_url():
    ADK_PORT = "8081"
    url = f"http://localhost:{ADK_PORT}/dev-ui/"

    styled_html = f"""
    <div style="padding: 15px; border: 2px solid #f0ad4e;
    border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
    <div style="font-family: sans-serif; margin-bottom: 12px;
    color:#333; font-size: 1.1em;">
    <strong> IMPORTANT : Action Required </strong>
    </div>
    <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
        The ADK web UI is <strong>not running yet</strong>.
        You must start it in the cell. 
        <ol style="margin-top: 10px; padding-left: 20px;">
                <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!cd sample-agent && adk web ...</code>) to start the ADK web UI on port 8081.</li>
                <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
                <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
            </ol>
            <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
        </div>
        <a href='{url}' target='_blank' style="
            display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
            text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
            box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
            Open ADK Web UI (after running cell below) ↗
        </a>
    </div>
    """
    display(HTML(styled_html))

    return url

print("Helper function defined !")
# Out:
# Helper function defined !

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  
    exp_base=7,  
    initial_delay=1, 
    http_status_codes=[429, 500, 503, 504] 
)

# %%
root_agent = Agent(
    name="helpful_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
)

print("Root Agent Define.")
# Out:
# Root Agent Define.

# %%
runner = InMemoryRunner(agent=root_agent)
print("Runner Created.")
# Out:
# Runner Created.

# %%
response = await runner.run_debug(
    "What is the capital of france"
)
# Out:
#  ### Continue session: debug_session_id
#
# User > What is the capital of france
# helpful_assistant > The capital of France is Paris.

# %%
response1 = await runner.run_debug(
    "what is the capital of india"
)
# Out:
#  ### Continue session: debug_session_id
#
# User > what is the capital of india
# helpful_assistant > The capital of India is New Delhi.

# %% [markdown]
# ### here we go again

# %%
# !adk create sampleAgent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
# Out:
# Agent created in c:\Users\adity\OneDrive\Documents\GitHub\kaggle-Hackthon\sampleAgent:
# - .env
# - __init__.py
# - agent.py

# %%
root_agent = Agent(
    name="Coding_Assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A coding agent that can write and execute code to answer user questions.",
    instruction="You are a helpful agent that can write and execute code to answer user questions.",
)

print("Coding Agent Define.")
# Out:
# Coding Agent Define.

# %%
code_runner = InMemoryRunner(agent=code_agent)
print("Code Assistant Runner Created.")
# Out:
# Code Assistant Runner Created.

# %%
response = await code_runner.run_debug(
    "what is the code of c++ for Adding two number "
)
# Out:
#  ### Created new session: debug_session_id
#
# User > what is the code of c++ for Adding two number
# Coding_Assistant > ```cpp
# #include <iostream>
#
# int main() {
#   // Declare two integer variables
#   int num1, num2, sum;
#
#   // Prompt the user to enter the first number
#   std::cout << "Enter the first number: ";
#   std::cin >> num1;
#
#   // Prompt the user to enter the second number
#   std::cout << "Enter the second number: ";
#   std::cin >> num2;
#
#   // Add the two numbers and store the result in 'sum'
#   sum = num1 + num2;
#
#   // Display the sum
#   std::cout << "The sum of " << num1 << " and " << num2 << " is: " << sum << std::endl;
#
#   return 0; // Indicate successful execution
# }
# ```
#
# **Explanation:**
#
# 1.  **`#include <iostream>`:** This line includes the input/output stream library, which provides functionalities for interacting with the user (like printing to the console and reading input).
#
# 2.  **`int main() { ... }`:** This is the main function where the program execution begins.
#
# 3.  **`int num1, num2, sum;`:** This declares three integer variables:
#     *   `num1`: To store the first number entered by the user.
#     *   `num2`: To store the second number entered by the user.
#     *   `sum`: To store the result of the addition.
#
# 4.  **`std::cout << "Enter the first number: ";`:** This line uses `std::cout` (character output) to display a message on the console, prompting the user to enter the first number.
#
# 5.  **`std::cin >> num1;`:** This line uses `std::cin` (character input) to read the number entered by the user from the console and store it in the `num1` variable.
#
# 6.  **`std::cout << "Enter the second number: ";`:** Similar to step 4, this prompts the user for the second number.
#
# 7.  **`std::cin >> num2;`:** Similar to step 5, this reads the second number and stores it in `num2`.
#
# 8.  **`sum = num1 + num2;`:** This is the core of the addition. It adds the values stored in `num1` and `num2` and assigns the result to the `sum` variable.
#
# 9.  **`std::cout << "The sum of " << num1 << " and " << num2 << " is: " << sum << std::endl;`:** This line displays the result to the user. It concatenates strings and the values of the variables to form a readable output message.
#     *   `std::endl` inserts a newline character, moving the cursor to the next line for subsequent output.
#
# 10. **`return 0;`:** This statement indicates that the `main` function has executed successfully. A return value of 0 is conventionally used for successful program termination.
#
# **How to compile and run this code:**
#
# 1.  **Save:** Save the code in a file named something like `add_numbers.cpp`.
# 2.  **Compile:** Open a terminal or command prompt and use a C++ compiler (like g++) to compile the code:
#     ```bash
#     g++ add_numbers.cpp -o add_numbers
#     ```
# 3.  **Run:** Execute the compiled program:
#     ```bash
#     ./add_numbers
#     ```
#
# The program will then prompt you to enter two numbers, and after you do, it will display their sum.

# %%
response1 = await code_runner.run_debug(
    "what is C code to print 'Hello World'"
)
# Out:
#  ### Continue session: debug_session_id
#
# User > what is C code to print 'Hello World'
# Coding_Assistant > Here's the C code to print "Hello World":
#
# ```c
# #include <stdio.h>
#
# int main() {
#     // The printf function is used to print output to the console
#     printf("Hello World\n");
#     return 0; // Indicates successful execution
# }
# ```
#
# **Explanation:**
#
# 1.  **`#include <stdio.h>`:** This line is a preprocessor directive. It tells the C compiler to include the standard input/output library (`stdio.h`). This library contains functions for input and output operations, such as `printf`.
#
# 2.  **`int main() { ... }`:** This is the `main` function. In C, program execution always begins in the `main` function.
#     *   `int` specifies that the `main` function will return an integer value.
#     *   The curly braces `{}` enclose the block of code that belongs to the `main` function.
#
# 3.  **`printf("Hello World\n");`:** This is the core of the program.
#     *   `printf` is a function from the `stdio.h` library that stands for "print formatted".
#     *   The text inside the double quotes (`"Hello World\n"`) is the string that will be printed to the console.
#     *   `\n` is an escape sequence that represents a newline character. This means that after printing "Hello World", the cursor will move to the next line.
#
# 4.  **`return 0;`:** This statement signifies the end of the `main` function. Returning `0` is a convention in C to indicate that the program executed successfully without any errors.
#
# **How to compile and run this code:**
#
# 1.  **Save:** Save the code in a file named something like `hello.c`.
# 2.  **Compile:** Open a terminal or command prompt and use a C compiler (like `gcc`) to compile the code:
#     ```bash
#     gcc hello.c -o hello
#     ```
#     *   `gcc` is the GNU C Compiler.
#     *   `hello.c` is your source code file.
#     *   `-o hello` specifies that the output executable file should be named `hello`.
# 3.  **Run:** Execute the compiled program:
#     ```bash
#     ./hello
#     ```
#     (On Windows, you might just type `hello` and press Enter).
#
# You will then see the following output in your terminal:
#
# ```
# Hello World
# ```

# %%
# !adk create codingAssistant --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
# Out:
# Agent created in c:\Users\adity\OneDrive\Documents\GitHub\kaggle-Hackthon\codingAssistant:
# - .env
# - __init__.py
# - agent.py

# %% [markdown]
# ### To run these Agent in ADK web environment type this in terminal
#
# ```bash
# adk web
# ```
# #### if your file structure is like this
#
# ```bash
# Root-folder/
# ├── mainArch.ipynb              # Main notebook with agent setup
# ├── sampleAgent/                # Sample agent package
# │   ├── __init__.py
# │   └── agent.py               # Root agent definition
# ├── codingAssistant/            # Coding assistant agent package
# │   ├── __init__.py
# │   └── agent.py               # Coding agent definition
#
# ├── .env.example                # Environment variables template
# ├── .gitignore                  # Git ignore configuration
# └── README.md                   # This file
# ```
